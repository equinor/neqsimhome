# %% [markdown]
# # Field Development: Concepts, Gates and Deliverables — Cost-Influence Curve and FEL
#
# This companion notebook is part of the TPG4230 distribution bundle. It regenerates the figures for section ch11_s02; run all cells from top to bottom to reproduce the saved PNG files.

# %% [markdown]
# ## Figure — Cost-influence curve and decision-gate placement
#
# Produces ``ch11_s02_influence.png``.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

os.makedirs("../figures", exist_ok=True)
t = np.linspace(0, 1, 200)
influence = 100 * np.exp(-3.5 * t)
cum_cost = 100 * (1 - np.exp(-3.0 * t))

fig, ax = plt.subplots(figsize=(8.5, 5.0))
ax.plot(t, influence, color="#1f77b4", lw=2.5,
        label="Ability to influence outcome")
ax.plot(t, cum_cost, color="#d62728", lw=2.5,
        label="Cumulative project cost")
gates = {0.10: "DG1", 0.25: "DG2", 0.45: "DG3", 0.85: "DG4"}
for x, lbl in gates.items():
    ax.axvline(x, color="#888", lw=0.8, ls="--")
    ax.text(x, 105, lbl, ha="center", fontsize=8.5, color="#444")
ax.set_xlabel("Project time (normalised)")
ax.set_ylabel("Relative magnitude (%)")
ax.set_xlim(0, 1); ax.set_ylim(0, 115)
ax.legend(loc="center right", frameon=False); ax.grid(alpha=0.25)
ax.set_title("Cost-influence curve and decision-gate placement", fontsize=11)
ax.spines["top"].set_visible(False); ax.spines["right"].set_visible(False)
fig.tight_layout()
fig.savefig("../figures/ch11_s02_influence.png", dpi=150, bbox_inches="tight")
plt.close(fig)
print("wrote ../figures/ch11_s02_influence.png")
# Out:
# wrote ../figures/ch11_s02_influence.png

# %% [markdown]
# All figures written to ``../figures/``.
