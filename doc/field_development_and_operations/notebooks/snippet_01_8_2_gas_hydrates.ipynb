# %% [markdown]
# # ch08_flow_assurance_gas_processing — 8.2 Gas hydrates
#
# From chapter `ch08_flow_assurance_gas_processing`, section: **8.2 Gas hydrates**.
#
# This companion notebook reproduces or expands the textbook code block. Run all cells from top to bottom; cells that are intentionally illustrative are marked in the code comments.

# %%
from neqsim import jneqsim as ns

fluid = ns.thermo.system.SystemSrkCPAstatoil(280.0, 80.0)
fluid.addComponent("methane", 0.85)
fluid.addComponent("ethane",  0.07)
fluid.addComponent("propane", 0.04)
fluid.addComponent("CO2",     0.04)
fluid.addComponent("water",   1.0)   # excess water
fluid.createDatabase(True)
fluid.setMixingRule(10)              # CPA mixing rule
fluid.setMultiPhaseCheck(True)
fluid.setHydrateCheck(True)

ops = ns.thermodynamicoperations.ThermodynamicOperations(fluid)
ops.hydrateFormationTemperature()
T_hyd = fluid.getTemperature() - 273.15
print(f"Hydrate T at 80 bar = {T_hyd:.2f} °C")
# Out:
# Hydrate T at 80 bar = 19.44 °C
