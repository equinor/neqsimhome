# %% [markdown]
# # ch20_production_optimisation — 20.3 NeqSim optimisation toolkit
#
# From chapter `ch20_production_optimisation`, section: **20.3 NeqSim optimisation toolkit**.
#
# This companion notebook reproduces or expands the textbook code block. Run all cells from top to bottom; cells that are intentionally illustrative are marked in the code comments.

# %%
# Pseudocode pattern (illustrative — wire to your build_field_process()):
#
# from neqsim import jneqsim as ns
# process = build_field_process()         # returns a ProcessSystem
# opt = ns.process.optimization.ProductionOptimizer(process)
# opt.addDecisionVariable("Well-1.choke", lower=0.1, upper=1.0)
# ...
# opt.addConstraint("HP-Sep.gasFlowRate", upper=1e7)    # Sm³/d
# opt.setObjective("HP-Sep.oilFlowRate", maximize=True)
# opt.run()
# print(opt.getOptimalVariables(), opt.getOptimalObjective())
print("Illustrative API pattern only: replace the commented builder with a concrete ProcessSystem before running optimization.")
# Out:
# Illustrative API pattern only: replace the commented builder with a concrete ProcessSystem before running optimization.
