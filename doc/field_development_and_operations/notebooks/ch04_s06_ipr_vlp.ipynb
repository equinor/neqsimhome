# %% [markdown]
# # Flow Performance in Production Systems — Nodal Analysis
#
# This companion notebook is part of the TPG4230 distribution bundle. It regenerates the figures for section ch04_s06; run all cells from top to bottom to reproduce the saved PNG files.

# %% [markdown]
# ## Figure — IPR and VLP intersection for a gas well — nodal-analysis operating point
#
# Produces ``ch04_s06_ipr_vlp.png``.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

os.makedirs("../figures", exist_ok=True)
q = np.linspace(0, 1.2e6, 100)        # Sm3/d
P_res = 250.0                         # bara
PI    = 1.0e-5                        # Sm3/d/bar^2
P_wf_ipr = np.sqrt(np.maximum(P_res**2 - q / PI, 0))   # Vogel-like
P_wh = 50.0
P_wf_vlp = P_wh + 0.05 * q / 1e3 + 1.0e-11 * q**2

fig, ax = plt.subplots(figsize=(7.5, 4.8))
ax.plot(q / 1e3, P_wf_ipr, color="#d62728", lw=2.4, label="IPR (reservoir)")
ax.plot(q / 1e3, P_wf_vlp, color="#1f77b4", lw=2.4, label="VLP (tubing)")
# Operating point: intersection by interpolation
diff = P_wf_ipr - P_wf_vlp
idx  = int(np.argmin(np.abs(diff)))
ax.plot(q[idx] / 1e3, P_wf_ipr[idx], "o", color="#000", ms=8,
        label=f"Operating point  ({q[idx]/1e3:.0f} kSm$^3$/d)")
ax.set_xlabel("Gas rate (kSm³/d)"); ax.set_ylabel("Bottomhole pressure (bara)")
ax.set_title("IPR and VLP intersection for a gas well — nodal-analysis operating point", fontsize=11)
ax.legend(frameon=False); ax.grid(alpha=0.3)
ax.spines["top"].set_visible(False); ax.spines["right"].set_visible(False)
fig.tight_layout()
fig.savefig("../figures/ch04_s06_ipr_vlp.png", dpi=150, bbox_inches="tight")
plt.close(fig)
print("wrote ../figures/ch04_s06_ipr_vlp.png")
# Out:
# wrote ../figures/ch04_s06_ipr_vlp.png

# %% [markdown]
# All figures written to ``../figures/``.
