# %% [markdown]
# # Field Development: Concepts, Gates and Deliverables — Concept Selection (DG2)
#
# This companion notebook is part of the TPG4230 distribution bundle. It regenerates the figures for section ch11_s06; run all cells from top to bottom to reproduce the saved PNG files.

# %% [markdown]
# ## Figure — Concept selection bar chart — CAPEX, NPV, CO₂ and first oil
#
# Produces ``ch11_s06_concept_screen.png``.

# %%
import os
import matplotlib.pyplot as plt

os.makedirs("../figures", exist_ok=True)
concepts = ["Subsea\ntieback", "FPSO", "Fixed\nplatform"]
metrics = {
    "CAPEX (B¤)":      [1.2, 3.5, 4.1],
    "NPV (B¤)":        [2.4, 1.8, 1.4],
    "CO₂ (kt/yr)":     [12.0, 95.0, 82.0],
    "First oil (yrs)":      [3.0, 4.5, 5.5],
}
colors = ["#1f77b4", "#d97706", "#2ca02c"]
fig, axs = plt.subplots(1, 4, figsize=(12.0, 3.6))
for ax, (name, vals) in zip(axs, metrics.items()):
    ax.bar(concepts, vals, color=colors, edgecolor="#333")
    ax.set_title(name, fontsize=10); ax.grid(axis="y", alpha=0.25)
    ax.spines["top"].set_visible(False); ax.spines["right"].set_visible(False)
    for i, v in enumerate(vals):
        ax.text(i, v, f" {v:.1f}", ha="center", va="bottom", fontsize=9)
fig.suptitle("Concept selection bar chart — CAPEX, NPV, CO₂ and first oil", fontsize=11)
fig.tight_layout(rect=(0, 0, 1, 0.93))
fig.savefig("../figures/ch11_s06_concept_screen.png", dpi=150, bbox_inches="tight")
plt.close(fig)
print("wrote ../figures/ch11_s06_concept_screen.png")
# Out:
# wrote ../figures/ch11_s06_concept_screen.png

# %% [markdown]
# All figures written to ``../figures/``.
