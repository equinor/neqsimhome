# %% [markdown]
# # Economic Analysis: NPV, IRR, Fiscal Regimes and Uncertainty — Exlandian Fiscal Regime (Ultima Thule case)
#
# This companion notebook is part of the TPG4230 distribution bundle. It regenerates the figures for section ch18_s04; run all cells from top to bottom to reproduce the saved PNG files.

# %% [markdown]
# ## Figure — Tornado diagram of Ultima Thule NPV under ±30 % parameter swings
#
# Produces ``ch18_s04_tornado.png``.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

os.makedirs("../figures", exist_ok=True)
params = ["Oil price",
          "Reserves",
          "CAPEX",
          "Schedule slip",
          "OPEX",
          "Recovery factor",
          "Discount rate"]
low  = np.array([-1100, -900, -650, -380, -220, -180,  -90])
high = np.array([+1300, +860, +580, +260, +200, +210,  +110])
order = np.argsort(np.abs(high - low))[::-1]
y = np.arange(len(params))

fig, ax = plt.subplots(figsize=(8.5, 5.0))
ax.barh(y, high[order], color="#2ca02c", label="High")
ax.barh(y, low[order],  color="#d62728", label="Low")
ax.axvline(0, color="#333", lw=1.0)
ax.set_yticks(y); ax.set_yticklabels(np.array(params)[order])
ax.invert_yaxis()
ax.set_xlabel("Δ NPV (M\u00a4)")
ax.set_title("Tornado diagram of Ultima Thule NPV under ±30 % parameter swings", fontsize=11)
ax.legend(loc="lower right", frameon=False)
ax.grid(axis="x", alpha=0.3)
ax.spines["top"].set_visible(False); ax.spines["right"].set_visible(False)
fig.tight_layout()
fig.savefig("../figures/ch18_s04_tornado.png", dpi=150, bbox_inches="tight")
plt.close(fig)
print("wrote ../figures/ch18_s04_tornado.png")
# Out:
# wrote ../figures/ch18_s04_tornado.png

# %% [markdown]
# All figures written to ``../figures/``.
